# %%
import os
import sys
from pathlib import Path

# Dynamically locate project root and set working dir
project_root = Path().resolve().parents[1]
os.chdir(project_root)
sys.path.append(str(project_root))

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from catboost import CatBoostRegressor, Pool
import optuna
from typing import Union, Dict, Tuple
from sklearn.model_selection import TimeSeriesSplit
from ydata_profiling import ProfileReport
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.ensemble import RandomForestRegressor as RF
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %% [markdown]
# # Table of Contents
# - [Dataset Preparation](#Dataset-Preparation)
# - [Baseline Model](#Baseline-Model)
# - [Baseline Model with target lag features](#Baseline-Model-with-Target-Lag-Features)
# - [Baseline Model with all lag features](#Baseline-Model-with-All-Lag-Features)
# - [Gradient Boosting with Hyperparameters Tuning](#Gradient-Boosting-with-Hyperparameters-Tuning)
# - [Conclusions](#Conclusions)

# %% [markdown]
# # Preprocessing

# %%
# Loading the data
data = pd.read_parquet('./data/raw_data/raw_data_full.parquet')

# %%
data.head(3)
# Out:
#               datetime  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0  2011-01-01 00:00:00       1   0     1   0        0        6           0
# 1  2011-01-01 01:00:00       1   0     1   1        0        6           0
# 2  2011-01-01 02:00:00       1   0     1   2        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32

# %% [markdown]
# Let's drop the columns that are not required for further analysis and modeling.
#
# - 'yr' does not seem to help because it
# - 'casual', 'registered' are already included in the target column 'cnt'

# %%
drop_cols = ['yr', 'casual', 'registered', 'datetime']

# %%
data = data.drop(columns=drop_cols)

# %%
data.head(3)
# Out:
#    season  mnth  hr  holiday  weekday  workingday  weathersit  temp   atemp  \
# 0       1     1   0        0        6           0           1  0.24  0.2879
# 1       1     1   1        0        6           0           1  0.22  0.2727
# 2       1     1   2        0        6           0           1  0.22  0.2727
#
#     hum  windspeed  cnt
# 0  0.81        0.0   16
# 1  0.80        0.0   40
# 2  0.80        0.0   32

# %% [markdown]
# # Baseline Model

# %% [markdown]
# We will use Random Forest using Raw Features as the Baseline Model because it does not require much tuning.
#
# Then, we will add features and try other algorithms to see how big the improvement is.
#
# For the metrics, we will use:
# - MAPE
# - MAE
# - RMSE

# %%
def compute_metrics(
    y_true: Union[np.ndarray, list], 
    y_pred: Union[np.ndarray, list]
) -> Dict[str, float]:
    """
    Compute evaluation metrics between true and predicted values.

    Metrics returned:
    - MAPE: Mean Absolute Percentage Error (in %)
    - MAE: Mean Absolute Error
    - RMSE: Root Mean Squared Error

    Parameters:
    ----------
    y_true : array-like
        Ground truth values.
    y_pred : array-like
        Predicted values.

    Returns:
    -------
    dict
        Dictionary with keys 'MAPE', 'MAE', and 'RMSE' and their float values.
    """
    mae = mean_absolute_error(y_true, y_pred)
    rmse = mean_squared_error(y_true, y_pred, squared=False)

    y_true = np.array(y_true)
    y_pred = np.array(y_pred)

    mape = np.mean(np.abs((y_true - y_pred) / np.where(y_true == 0, 0.01, y_true))) * 100

    return {
        'MAE': round(mae, 2),
        'RMSE': round(rmse, 2),
        'MAPE': round(mape, 2)
    }

# %%
def prepare_dataset(
    df: pd.DataFrame, 
    train_fraction: float = 0.8
) -> Tuple[pd.DataFrame, pd.DataFrame, pd.Series, pd.Series]:
    """
    Splits a DataFrame into training and testing sets for features and target.

    Parameters:
    ----------
    df : pd.DataFrame
        The input DataFrame that must contain a 'target' column.
    train_fraction : float, optional (default=0.8)
        The fraction of data to use for training (between 0 and 1).

    Returns:
    -------
    x_train : pd.DataFrame
        Training features.
    x_test : pd.DataFrame
        Testing features.
    y_train : pd.Series
        Training target values.
    y_test : pd.Series
        Testing target values.
    """
    feats = [col for col in df.columns if col != 'target']
    x, y = df[feats], df['target']
    train_size = int(train_fraction * df.shape[0])
    x_train, x_test = x[:train_size], x[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]
    return x_train, x_test, y_train, y_test

# %% [markdown]
# #### Target definition
#
# For the target, we will use the next hour bike count because we want to predict what this value will be ti adjust the pricing.

# %% [markdown]
# ## Training

# %%
df = data.copy()

# %%
df['target'] = df['cnt'].shift(-1).fillna(method='ffill')
df.drop(columns=['cnt'], inplace=True)

# %%
x_train, x_test, y_train, y_test = prepare_dataset(df, train_fraction=0.8)

# %%
# %%time
model = RF(n_estimators=100)
model.fit(x_train, y_train)
# Out:
# CPU times: user 2.18 s, sys: 14.7 ms, total: 2.19 s
# Wall time: 2.21 s
# RandomForestRegressor()

# %% [markdown]
# ## Inference

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# ## Postprocessing

# %%
metrics_base = compute_metrics(y_test.values, y_pred)
metrics_base
# Out:
# {'MAE': 85.28, 'RMSE': 123.62, 'MAPE': 39.06}

# %%
n = 300
plt.plot(y_test.values[:n], label='y_test')
plt.plot(y_pred[:n], label='y_pred')
plt.legend()

# %% [markdown]
# **Observations**
#
# - We see that values below 200 are well predicted
# - We see that the peaks are significantly underpredicted.

# %% [markdown]
# **Dummy model**
#
# A dummy model is the model that tells that the next target value is the same as the previous value.

# %%
y_dummy = y_test.shift(1).fillna(method='bfill')
metrics_dummy = compute_metrics(y_test.values, y_dummy)

# %%
print('Dummy model scores:', metrics_dummy)
print('Baseline model scores:', metrics_base)
# Out:
# Dummy model scores: {'MAE': 85.15, 'RMSE': 129.65, 'MAPE': 54.52}
# Baseline model scores: {'MAE': 85.28, 'RMSE': 123.62, 'MAPE': 39.06}

# %% [markdown]
# We see that our Baseline Model does not do much better that the dummy model
#
# We see that only the MAPE metrics decreased quite well, while the other two are not, especially MAE.
#
# This gives the conclusion that some feature engineering is definteily required.

# %% [markdown]
# # Baseline Model with Target Lag Features

# %% [markdown]
# A good idea is to add the lagged values of the target because we assume it's goona be available by the time we make the predictions for the next hour.
#
# To understand how many lagged features we need, let's compute autocorrelation for the target.

# %%
# Let's compute autocorrelation
for lag in range(1, 25):
    print(f"Lag {lag}: {df['target'].autocorr(lag=lag):.3f}")
# Out:
# Lag 1: 0.844
# Lag 2: 0.594
# Lag 3: 0.404
# Lag 4: 0.272
# Lag 5: 0.146
# Lag 6: 0.010
# Lag 7: -0.093
# Lag 8: -0.113
# Lag 9: -0.058
# Lag 10: -0.054
# Lag 11: -0.107
# Lag 12: -0.140
# Lag 13: -0.114
# Lag 14: -0.064
# Lag 15: -0.060
# Lag 16: -0.093
# Lag 17: -0.063
# Lag 18: 0.036
# Lag 19: 0.156
# Lag 20: 0.265
# Lag 21: 0.373
# Lag 22: 0.522
# Lag 23: 0.710
# Lag 24: 0.816

# %% [markdown]
# We see that the autocrrelations are high for the first and last 3 values that indicates a strong daily seasonality.
#
# Let's add this lags.

# %% [markdown]
# When the model to be run in production, from the pipeline perspective, it's better to have the 'cnt' column back and take the lags relative to it to avoid confusion.

# %% [markdown]
# ## Feature Engineering

# %%
df = data.copy()
df['target'] = df['cnt'].shift(-1).fillna(method='ffill')
df.head(3)
# Out:
#    season  mnth  hr  holiday  weekday  workingday  weathersit  temp   atemp  \
# 0       1     1   0        0        6           0           1  0.24  0.2879
# 1       1     1   1        0        6           0           1  0.22  0.2727
# 2       1     1   2        0        6           0           1  0.22  0.2727
#
#     hum  windspeed  cnt  target
# 0  0.81        0.0   16    40.0
# 1  0.80        0.0   40    32.0
# 2  0.80        0.0   32    13.0

# %% [markdown]
# The 'cnt' column is alread 1 lag behind the target, so we need to make shifts of the 'cnt' column from 1 to 2 and from 22 to 23.

# %%
# Add first 2 lags
for i in range(1, 3):
    df[f'cnt_lag_{i}'] = df['cnt'].shift(i).fillna(method='bfill')

# Add last 2 lags
for i in range(22, 24):
    df[f'cnt_lag_{i}'] = df['cnt'].shift(i).fillna(method='bfill')

# %%
df.head(3)
# Out:
#    season  mnth  hr  holiday  weekday  workingday  weathersit  temp   atemp  \
# 0       1     1   0        0        6           0           1  0.24  0.2879
# 1       1     1   1        0        6           0           1  0.22  0.2727
# 2       1     1   2        0        6           0           1  0.22  0.2727
#
#     hum  windspeed  cnt  target  cnt_lag_1  cnt_lag_2  cnt_lag_22  cnt_lag_23
# 0  0.81        0.0   16    40.0       16.0       16.0        16.0        16.0
# 1  0.80        0.0   40    32.0       16.0       16.0        16.0        16.0
# 2  0.80        0.0   32    13.0       40.0       16.0        16.0        16.0

# %% [markdown]
# ## Training

# %% [markdown]
# Let's see if this helps the model

# %%
x_train, x_test, y_train, y_test = prepare_dataset(df, train_fraction=0.8)

# %%
x_train
# Out:
#        season  mnth  hr  holiday  weekday  workingday  weathersit  temp  \
# 0           1     1   0        0        6           0           1  0.24
# 1           1     1   1        0        6           0           1  0.22
# 2           1     1   2        0        6           0           1  0.22
# 3           1     1   3        0        6           0           1  0.24
# 4           1     1   4        0        6           0           1  0.24
# ...       ...   ...  ..      ...      ...         ...         ...   ...
# 13898       3     8   7        0        2           1           2  0.70
# 13899       3     8   8        0        2           1           2  0.70
# 13900       3     8   9        0        2           1           2  0.70
# 13901       3     8  10        0        2           1           2  0.74
# 13902       3     8  11        0        2           1           2  0.76
#
#         atemp   hum  windspeed  cnt  cnt_lag_1  cnt_lag_2  cnt_lag_22  \
# 0      0.2879  0.81     0.0000   16       16.0       16.0        16.0
# 1      0.2727  0.80     0.0000   40       16.0       16.0        16.0
# 2      0.2727  0.80     0.0000   32       40.0       16.0        16.0
# 3      0.2879  0.75     0.0000   13       32.0       40.0        16.0
# 4      0.2879  0.75     0.0000    1       13.0       32.0        16.0
# ...       ...   ...        ...  ...        ...        ...         ...
# 13898  0.6667  0.74     0.1343  502      179.0       36.0       276.0
# 13899  0.6515  0.70     0.1642  705      502.0      179.0       213.0
# 13900  0.6667  0.74     0.1343  327      705.0      502.0       260.0
# 13901  0.6970  0.70     0.1343  250      327.0      705.0       285.0
# 13902  0.7273  0.66     0.0896  214      250.0      327.0       289.0
#
#        cnt_lag_23
# 0            16.0
# 1            16.0
# 2            16.0
# 3            16.0
# 4            16.0
# ...           ...
# 13898       605.0
# 13899       276.0
# 13900       213.0
# 13901       260.0
# 13902       285.0
#
# [13903 rows x 16 columns]

# %%
model = RF(n_estimators=100)
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# ## Inference

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# ## Postprocessing

# %%
metrics_target_lag = compute_metrics(y_test.values, y_pred)
metrics_target_lag
# Out:
# {'MAE': 32.14, 'RMSE': 54.58, 'MAPE': 22.79}

# %%
print('Baseline model scores:', metrics_base)
print('Baseline model with target lags scores:', metrics_target_lag)
# Out:
# Baseline model scores: {'MAE': 85.28, 'RMSE': 123.62, 'MAPE': 39.06}
# Baseline model with target lags scores: {'MAE': 32.14, 'RMSE': 54.58, 'MAPE': 22.79}

# %%
n = 300
plt.plot(y_test.values[:n], label='y_test')
plt.plot(y_pred[:n], label='y_pred')
plt.legend()

# %% [markdown]
# Now we see a significant imporvement.
#
# We clearly see that the peaks now are better captured.

# %% [markdown]
# # Baseline Model with All Lag Features

# %% [markdown]
# Let's add the lag features for other features, not only for the target.
#
# We will add only the first 3 lags, you can experiment with different lags and see the performance

# %%
df.columns
# Out:
# Index(['season', 'mnth', 'hr', 'holiday', 'weekday', 'workingday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'cnt', 'target',
#        'cnt_lag_1', 'cnt_lag_2', 'cnt_lag_22', 'cnt_lag_23'],
#       dtype='object')

# %% [markdown]
# ## Feature Engineering

# %%
lag_feats = ['hr', 'weekday', 'weathersit', 'temp', 'hum']

n = 3
for feat in lag_feats:
    for i in range(1, n+1):
        df[f'{feat}_lag_{i}'] = df[feat].shift(i).fillna(method='bfill')

# %% [markdown]
# ## Training

# %%
x_train, x_test, y_train, y_test = prepare_dataset(df, train_fraction=0.8)

# %%
x_train.head(3)
# Out:
#    season  mnth  hr  holiday  weekday  workingday  weathersit  temp   atemp  \
# 0       1     1   0        0        6           0           1  0.24  0.2879
# 1       1     1   1        0        6           0           1  0.22  0.2727
# 2       1     1   2        0        6           0           1  0.22  0.2727
#
#     hum  ...  weekday_lag_3  weathersit_lag_1  weathersit_lag_2  \
# 0  0.81  ...            6.0               1.0               1.0
# 1  0.80  ...            6.0               1.0               1.0
# 2  0.80  ...            6.0               1.0               1.0
#
#    weathersit_lag_3  temp_lag_1  temp_lag_2  temp_lag_3  hum_lag_1  hum_lag_2  \
# 0               1.0        0.24        0.24        0.24       0.81       0.81
# 1               1.0        0.24        0.24        0.24       0.81       0.81
# 2               1.0        0.22        0.24        0.24       0.80       0.81
#
#    hum_lag_3
# 0       0.81
# 1       0.81
# 2       0.81
#
# [3 rows x 31 columns]

# %%
x_train.columns
# Out:
# Index(['season', 'mnth', 'hr', 'holiday', 'weekday', 'workingday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'cnt', 'cnt_lag_1',
#        'cnt_lag_2', 'cnt_lag_22', 'cnt_lag_23', 'hr_lag_1', 'hr_lag_2',
#        'hr_lag_3', 'weekday_lag_1', 'weekday_lag_2', 'weekday_lag_3',
#        'weathersit_lag_1', 'weathersit_lag_2', 'weathersit_lag_3',
#        'temp_lag_1', 'temp_lag_2', 'temp_lag_3', 'hum_lag_1', 'hum_lag_2',
#        'hum_lag_3'],
#       dtype='object')

# %%
# %%time
np.random.seed(23)
model = RF(n_estimators=100, verbose=1)
model.fit(x_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    4.1s
# CPU times: user 8.74 s, sys: 15.7 ms, total: 8.76 s
# Wall time: 8.44 s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    8.4s finished
# RandomForestRegressor(verbose=1)

# %% [markdown]
# ## Inference

# %%
y_pred = model.predict(x_test)
# Out:
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished

# %% [markdown]
# # Postprocessing

# %%
metrics_all_lags = compute_metrics(y_test.values, y_pred)
metrics_all_lags
# Out:
# {'MAE': 32.3, 'RMSE': 55.13, 'MAPE': 22.36}

# %%
print('Baseline model scores:', metrics_base)
print('Baseline model with target lags scores:', metrics_target_lag)
print('Baseline model with all lags scores:', metrics_all_lags)
# Out:
# Baseline model scores: {'MAE': 85.28, 'RMSE': 123.62, 'MAPE': 39.06}
# Baseline model with target lags scores: {'MAE': 32.14, 'RMSE': 54.58, 'MAPE': 22.79}
# Baseline model with all lags scores: {'MAE': 32.3, 'RMSE': 55.13, 'MAPE': 22.36}

# %% [markdown]
# We see that adding the feature lags futher improved the performance, but the improvement is not that big as before.
#
# However, with some basic feature engineering we still able to improve the scores and this we can add to the final production pipeline.

# %% [markdown]
# # Gradient Boosting with Hyperparameters Tuning

# %% [markdown]
# ## Training

# %%
df.reset_index(drop=True, inplace=True)

# %%
x_train, x_test, y_train, y_test = prepare_dataset(df, train_fraction=0.8)

# %%
x_train
# Out:
#        season  mnth  hr  holiday  weekday  workingday  weathersit  temp  \
# 0           1     1   0        0        6           0           1  0.24
# 1           1     1   1        0        6           0           1  0.22
# 2           1     1   2        0        6           0           1  0.22
# 3           1     1   3        0        6           0           1  0.24
# 4           1     1   4        0        6           0           1  0.24
# ...       ...   ...  ..      ...      ...         ...         ...   ...
# 13898       3     8   7        0        2           1           2  0.70
# 13899       3     8   8        0        2           1           2  0.70
# 13900       3     8   9        0        2           1           2  0.70
# 13901       3     8  10        0        2           1           2  0.74
# 13902       3     8  11        0        2           1           2  0.76
#
#         atemp   hum  ...  weekday_lag_3  weathersit_lag_1  weathersit_lag_2  \
# 0      0.2879  0.81  ...            6.0               1.0               1.0
# 1      0.2727  0.80  ...            6.0               1.0               1.0
# 2      0.2727  0.80  ...            6.0               1.0               1.0
# 3      0.2879  0.75  ...            6.0               1.0               1.0
# 4      0.2879  0.75  ...            6.0               1.0               1.0
# ...       ...   ...  ...            ...               ...               ...
# 13898  0.6667  0.74  ...            2.0               2.0               1.0
# 13899  0.6515  0.70  ...            2.0               2.0               2.0
# 13900  0.6667  0.74  ...            2.0               2.0               2.0
# 13901  0.6970  0.70  ...            2.0               2.0               2.0
# 13902  0.7273  0.66  ...            2.0               2.0               2.0
#
#        weathersit_lag_3  temp_lag_1  temp_lag_2  temp_lag_3  hum_lag_1  \
# 0                   1.0        0.24        0.24        0.24       0.81
# 1                   1.0        0.24        0.24        0.24       0.81
# 2                   1.0        0.22        0.24        0.24       0.80
# 3                   1.0        0.22        0.22        0.24       0.80
# 4                   1.0        0.24        0.22        0.22       0.75
# ...                 ...         ...         ...         ...        ...
# 13898               1.0        0.70        0.70        0.68       0.79
# 13899               1.0        0.70        0.70        0.70       0.74
# 13900               2.0        0.70        0.70        0.70       0.70
# 13901               2.0        0.70        0.70        0.70       0.74
# 13902               2.0        0.74        0.70        0.70       0.70
#
#        hum_lag_2  hum_lag_3
# 0           0.81       0.81
# 1           0.81       0.81
# 2           0.81       0.81
# 3           0.80       0.81
# 4           0.80       0.80
# ...          ...        ...
# 13898       0.79       0.83
# 13899       0.79       0.79
# 13900       0.74       0.79
# 13901       0.70       0.74
# 13902       0.74       0.70
#
# [13903 rows x 31 columns]

# %%
# Step 1: Define the Optuna objective with TimeSeriesSplit on x_train
def objective(trial):
    np.random.seed(42)
    params = {
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2),
        "depth": trial.suggest_int("depth", 3, 8),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 0.5, 5),
        "iterations": 1000,
        "loss_function": "RMSE",
        "verbose": 0
    }

    train_idx = int(0.85 * x_train.shape[0])

    x_tr, x_val = x_train.iloc[:train_idx], x_train.iloc[train_idx:]
    y_tr, y_val = y_train.iloc[:train_idx], y_train.iloc[train_idx:]

    model = CatBoostRegressor(**params, random_seed=42)
    model.fit(x_tr, y_tr,
              eval_set=(x_val, y_val),
              early_stopping_rounds=100,
              use_best_model=True)

    preds = model.predict(x_val)
    rmse = np.sqrt(mean_squared_error(y_val, preds))

    # Save best iteration
    trial.set_user_attr("best_iteration", model.get_best_iteration())

    return rmse

# %%
# Step 2: Run the Optuna study
study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=150)

# Step 4: Train final model on full x_train with best parameters
best_params = study.best_trial.params
# Out:
# [I 2025-08-07 15:31:11,909] A new study created in memory with name: no-name-49f7dadd-9b99-49d0-a144-f17a070220d5
# [I 2025-08-07 15:31:13,050] Trial 0 finished with value: 58.81042883240889 and parameters: {'learning_rate': 0.08116262258099886, 'depth': 8, 'l2_leaf_reg': 3.793972738151323}. Best is trial 0 with value: 58.81042883240889.
# [I 2025-08-07 15:31:13,604] Trial 1 finished with value: 53.899954985643085 and parameters: {'learning_rate': 0.12374511199743694, 'depth': 3, 'l2_leaf_reg': 1.201975341512912}. Best is trial 1 with value: 53.899954985643085.
# [I 2025-08-07 15:31:15,575] Trial 2 finished with value: 58.490011387089496 and parameters: {'learning_rate': 0.021035886311957897, 'depth': 8, 'l2_leaf_reg': 3.20501755284444}. Best is trial 1 with value: 53.899954985643085.
# [I 2025-08-07 15:31:15,965] Trial 3 finished with value: 54.52022048390632 and parameters: {'learning_rate': 0.14453378978124864, 'depth': 3, 'l2_leaf_reg': 4.864594334728975}. Best is trial 1 with value: 53.899954985643085.
# [I 2025-08-07 15:31:16,334] Trial 4 finished with value: 56.33945835163443 and parameters: {'learning_rate': 0.16816410175208013, 'depth': 4, 'l2_leaf_reg': 1.318212352431953}. Best is trial 1 with value: 53.899954985643085.
# [I 2025-08-07 15:31:17,034] Trial 5 finished with value: 55.46946166367573 and parameters: {'learning_rate': 0.044846856872152424, 'depth': 4, 'l2_leaf_reg': 2.86140394234507}. Best is trial 1 with value: 53.899954985643085.
# [I 2025-08-07 15:31:17,600] Trial 6 finished with value: 53.73282972129847 and parameters: {'learning_rate': 0.092069553542002, 'depth': 4, 'l2_leaf_reg': 3.2533380262507077}. Best is trial 6 with value: 53.73282972129847.
# [I 2025-08-07 15:31:18,350] Trial 7 finished with value: 55.5374737018217 and parameters: {'learning_rate': 0.036503833523887946, 'depth': 4, 'l2_leaf_reg': 2.148628294821613}. Best is trial 6 with value: 53.73282972129847.
# [I 2025-08-07 15:31:19,108] Trial 8 finished with value: 54.88381905072201 and parameters: {'learning_rate': 0.09665329700123683, 'depth': 7, 'l2_leaf_reg': 1.3985320197126188}. Best is trial 6 with value: 53.73282972129847.
# [I 2025-08-07 15:31:19,530] Trial 9 finished with value: 56.06831646456435 and parameters: {'learning_rate': 0.1077045432985862, 'depth': 6, 'l2_leaf_reg': 0.7090268572399898}. Best is trial 6 with value: 53.73282972129847.
# [I 2025-08-07 15:31:20,014] Trial 10 finished with value: 58.01596232929235 and parameters: {'learning_rate': 0.1895759434037735, 'depth': 5, 'l2_leaf_reg': 4.146207888434965}. Best is trial 6 with value: 53.73282972129847.
# [I 2025-08-07 15:31:20,654] Trial 11 finished with value: 52.503391728487955 and parameters: {'learning_rate': 0.13118913574102, 'depth': 3, 'l2_leaf_reg': 2.2911950399907948}. Best is trial 11 with value: 52.503391728487955.
# [I 2025-08-07 15:31:21,509] Trial 12 finished with value: 54.120299488270916 and parameters: {'learning_rate': 0.0681060890545777, 'depth': 5, 'l2_leaf_reg': 2.2222147961566683}. Best is trial 11 with value: 52.503391728487955.
# [I 2025-08-07 15:31:21,903] Trial 13 finished with value: 55.57128171342538 and parameters: {'learning_rate': 0.13230541995852646, 'depth': 3, 'l2_leaf_reg': 2.3295938726775764}. Best is trial 11 with value: 52.503391728487955.
# [I 2025-08-07 15:31
. Best is trial 121 with value: 51.62332947257353.
# [I 2025-08-07 15:32:18,677] Trial 126 finished with value: 53.92862024201552 and parameters: {'learning_rate': 0.18130662890282356, 'depth': 4, 'l2_leaf_reg': 0.912393053324504}. Best is trial 121 with value: 51.62332947257353.
# [I 2025-08-07 15:32:18,949] Trial 127 finished with value: 57.154167421324985 and parameters: {'learning_rate': 0.1927331757308503, 'depth': 4, 'l2_leaf_reg': 1.2466141371728359}. Best is trial 121 with value: 51.62332947257353.
# [I 2025-08-07 15:32:19,253] Trial 128 finished with value: 55.34906337137608 and parameters: {'learning_rate': 0.17522831628386523, 'depth': 4, 'l2_leaf_reg': 0.6593297546785415}. Best is trial 121 with value: 51.62332947257353.
# [I 2025-08-07 15:32:19,587] Trial 129 finished with value: 55.788751619402305 and parameters: {'learning_rate': 0.17145249755830155, 'depth': 4, 'l2_leaf_reg': 0.8288305026584423}. Best is trial 121 with value: 51.62332947257353.
# [I 2025-08-07 15:32:19,900] Trial 130 finished with value: 54.417009516244164 and parameters: {'learning_rate': 0.1820985942080274, 'depth': 4, 'l2_leaf_reg': 1.097965131803683}. Best is trial 121 with value: 51.62332947257353.
# [I 2025-08-07 15:32:20,283] Trial 131 finished with value: 53.063346217031594 and parameters: {'learning_rate': 0.1852747903704888, 'depth': 4, 'l2_leaf_reg': 0.5958497414377937}. Best is trial 121 with value: 51.62332947257353.
# [I 2025-08-07 15:32:20,566] Trial 132 finished with value: 53.79012856877331 and parameters: {'learning_rate': 0.18682104259095916, 'depth': 4, 'l2_leaf_reg': 0.7479069527027019}. Best is trial 121 with value: 51.62332947257353.
# [I 2025-08-07 15:32:20,948] Trial 133 finished with value: 56.602333545856574 and parameters: {'learning_rate': 0.19238153998929874, 'depth': 4, 'l2_leaf_reg': 0.921995957001933}. Best is trial 121 with value: 51.62332947257353.
# [I 2025-08-07 15:32:21,282] Trial 134 finished with value: 55.48875274690396 and parameters: {'learning_rate': 0.17959624635323632, 'depth': 4, 'l2_leaf_reg': 0.6732546520014269}. Best is trial 121 with value: 51.62332947257353.
# [I 2025-08-07 15:32:21,606] Trial 135 finished with value: 55.147777540563816 and parameters: {'learning_rate': 0.18964437977278806, 'depth': 4, 'l2_leaf_reg': 0.6271590219995961}. Best is trial 121 with value: 51.62332947257353.
# [I 2025-08-07 15:32:22,009] Trial 136 finished with value: 54.25372652731643 and parameters: {'learning_rate': 0.17074527860925165, 'depth': 4, 'l2_leaf_reg': 0.7887113122751906}. Best is trial 121 with value: 51.62332947257353.
# [I 2025-08-07 15:32:22,312] Trial 137 finished with value: 52.97128323780727 and parameters: {'learning_rate': 0.19991557609717062, 'depth': 4, 'l2_leaf_reg': 0.9719349335660095}. Best is trial 121 with value: 51.62332947257353.
# [I 2025-08-07 15:32:22,703] Trial 138 finished with value: 55.743370339980366 and parameters: {'learning_rate': 0.1948902100581481, 'depth': 4, 'l2_leaf_reg': 1.016332403954123}. Best is trial 121 with value: 51.62332947257353.
# [I 2025-08-07 15:32:23,067] Trial 139 finished with value: 53.30187967962504 and parameters: {'learning_rate': 0.17548499225109132, 'depth': 4, 'l2_leaf_reg': 1.1401054580479688}. Best is trial 121 with value: 51.62332947257353.
# [I 2025-08-07 15:32:23,375] Trial 140 finished with value: 55.12464253840516 and parameters: {'learning_rate': 0.16724087910642602, 'depth': 4, 'l2_leaf_reg': 0.5873352950893739}. Best is trial 121 with value: 51.62332947257353.
# [I 2025-08-07 15:32:23,831] Trial 141 finished with value: 53.21237944353463 and parameters: {'learning_rate': 0.18291898922067104, 'depth': 4, 'l2_leaf_reg': 0.8658138783234177}. Best is trial 121 with value: 51.62332947257353.
# [I 2025-08-07 15:32:24,151] Trial 142 finished with value: 54.40602831344113 and parameters: {'learning_rate': 0.199682211875261, 'depth': 4, 'l2_leaf_reg': 0.967326029843308}. Best is trial 121 with value: 51.62332947257353.
# [I 2025-08-07 15:32:24,423] Trial 143 finished with value: 54.315313513285396 and parameters: {'learning_rate': 0.18665921940848826, 'depth': 4, 'l2_leaf_reg': 0.712165958230321}. Best is trial 121 with value: 51.62332947257353.
# [I 2025-08-07 15:32:24,756] Trial 144 finished with value: 57.09637882109024 and parameters: {'learning_rate': 0.1775666158387511, 'depth': 4, 'l2_leaf_reg': 0.5121276526496994}. Best is trial 121 with value: 51.62332947257353.
# [I 2025-08-07 15:32:25,261] Trial 145 finished with value: 53.23421239907585 and parameters: {'learning_rate': 0.1847565724579994, 'depth': 4, 'l2_leaf_reg': 1.2946116874844444}. Best is trial 121 with value: 51.62332947257353.
# [I 2025-08-07 15:32:25,597] Trial 146 finished with value: 53.21996862716262 and parameters: {'learning_rate': 0.19074539898308113, 'depth': 4, 'l2_leaf_reg': 0.779665556618923}. Best is trial 121 with value: 51.62332947257353.
# [I 2025-08-07 15:32:25,935] Trial 147 finished with value: 55.338246932487365 and parameters: {'learning_rate': 0.18028881790912202, 'depth': 4, 'l2_leaf_reg': 0.920314188145322}. Best is trial 121 with value: 51.62332947257353.
# [I 2025-08-07 15:32:26,768] Trial 148 finished with value: 58.20769481950086 and parameters: {'learning_rate': 0.19423295262700535, 'depth': 7, 'l2_leaf_reg': 0.9979361914056638}. Best is trial 121 with value: 51.62332947257353.
# [I 2025-08-07 15:32:27,179] Trial 149 finished with value: 54.28126411860688 and parameters: {'learning_rate': 0.16404318367218035, 'depth': 4, 'l2_leaf_reg': 1.1683292001995897}. Best is trial 121 with value: 51.62332947257353.

# %%
best_trial = study.best_trial
print("Best RMSE:", best_trial.value)
print("Best iteration (trees):", best_trial.user_attrs["best_iteration"])
# Out:
# Best RMSE: 51.62332947257353
# Best iteration (trees): 416

# %%
best_params.update({
    "iterations": best_trial.user_attrs["best_iteration"],
    "loss_function": "RMSE",
    "verbose": 0
})

# %%
final_model = CatBoostRegressor(**best_params)
final_model.fit(x_train, y_train)

# %% [markdown]
# ## Inference

# %%
# Step 5: Predict on x_test and evaluate
y_pred = final_model.predict(x_test)

# %% [markdown]
# ## Postprocessing

# %%
metrics_catbost = compute_metrics(y_test.values, y_pred)
metrics_catbost
# Out:
# {'MAE': 31.14, 'RMSE': 48.92, 'MAPE': 24.81}

# %%
print('Baseline model scores:', metrics_base)
print('Baseline model with target lags scores:', metrics_target_lag)
print('Baseline model with all lags scores:', metrics_all_lags)
print('Tuned Catboost:', metrics_catbost)
# Out:
# Baseline model scores: {'MAE': 85.28, 'RMSE': 123.62, 'MAPE': 39.06}
# Baseline model with target lags scores: {'MAE': 32.14, 'RMSE': 54.58, 'MAPE': 22.79}
# Baseline model with all lags scores: {'MAE': 32.3, 'RMSE': 55.13, 'MAPE': 22.36}
# Tuned Catboost: {'MAE': 31.14, 'RMSE': 48.92, 'MAPE': 24.81}

# %%
best_params
# Out:
# {'learning_rate': 0.1833096275220571,
#  'depth': 4,
#  'l2_leaf_reg': 0.9607590220357451,
#  'iterations': 416,
#  'loss_function': 'RMSE',
#  'verbose': 0}

# %%
# Save the model to experiments
final_model.save_model('./models/experiments/final_catboost_model.cbm')

# %% [markdown]
# - We see that we are able to reduce the RMSE score and MAE score quite well.
# - MAPE score has not been reduced. However, since we have quite many values close to zero, MAPE is not a good metric in this case.
# - Note that in Bayesian Optiization we optimized for RMSE, we can also try to optimize for MAE.

# %% [markdown]
# # Conclusions

# %% [markdown]
# - The Baseline Random Foreset model with no feature engineering gave almost the same result as the dummy model (last value shifted forward)
# - Adding the target lags and feature lags improved the model significantly,
# - Changing Random Forest to Catboost and tuning Catboost Hyperparameters with Bayesian Optimization helped futher improve the scores.
# - For the production pipeline, we will use Catboost Model with Hyperparameter tuning.
